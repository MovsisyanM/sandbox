# %% [markdown]
# # Creating a deepstream pipeline

# %%
import sys
sys.path.append('../')
import gi
import configparser
gi.require_version('Gst', '1.0')
from gi.repository import GLib, Gst
from ctypes import *
import time
import sys
import math
import platform
from common.is_aarch_64 import is_aarch64
from common.bus_call import bus_call
from common.FPS import PERF_DATA

import cv2
import numpy as np

# %%
import pyds

# %%
import gi

perf_data = None

MAX_DISPLAY_LEN=64
pgie_classes_str= ["Vehicle", "Person", "Bike", "Roadsign"]

MUXER_OUTPUT_WIDTH=1920
MUXER_OUTPUT_HEIGHT=1080
MUXER_BATCH_TIMEOUT_USEC=4000000

TILED_OUTPUT_WIDTH=1280
TILED_OUTPUT_HEIGHT=720

GST_CAPS_FEATURES_NVMM="memory:NVMM"

OSD_PROCESS_MODE= 0
OSD_DISPLAY_TEXT= 1

args = ["testing.py", "/opt/nvidia/deepstream/deepstream-6.1/samples/streams/sample_qHD.h264", "/home/mher/projects/counter/sample_pyout.h264"]

# %%
from common.is_aarch_64 import is_aarch64
from common.bus_call import bus_call
from common.FPS import PERF_DATA

PGIE_CLASS_ID_VEHICLE = 2
PGIE_CLASS_ID_PERSON = 0
PGIE_CLASS_ID_BICYCLE = 1
PGIE_CLASS_ID_ROADSIGN = 3

TILED_OUTPUT_WIDTH = 1920
TILED_OUTPUT_HEIGHT = 1080

# %%
def osd_sink_pad_buffer_probe(pad,info,u_data):
    frame_number=0
    #Intiallizing object counter with 0.
    obj_counter = {
        PGIE_CLASS_ID_VEHICLE:0,
        PGIE_CLASS_ID_PERSON:0,
        PGIE_CLASS_ID_BICYCLE:0,
        PGIE_CLASS_ID_ROADSIGN:0
    }
    num_rects=0

    gst_buffer = info.get_buffer()
    if not gst_buffer:
        print("Unable to get GstBuffer ")
        return

    # Retrieve batch metadata from the gst_buffer
    # Note that pyds.gst_buffer_get_nvds_batch_meta() expects the
    # C address of gst_buffer as input, which is obtained with hash(gst_buffer)
    batch_meta = pyds.gst_buffer_get_nvds_batch_meta(hash(gst_buffer))
    l_frame = batch_meta.frame_meta_list
    while l_frame is not None:
        try:
            # Note that l_frame.data needs a cast to pyds.NvDsFrameMeta
            # The casting is done by pyds.glist_get_nvds_frame_meta()
            # The casting also keeps ownership of the underlying memory
            # in the C code, so the Python garbage collector will leave
            # it alone.
            #frame_meta = pyds.glist_get_nvds_frame_meta(l_frame.data)
            frame_meta = pyds.NvDsFrameMeta.cast(l_frame.data)
        except StopIteration:
            break

        frame_number=frame_meta.frame_num
        num_rects = frame_meta.num_obj_meta
        l_obj=frame_meta.obj_meta_list
        while l_obj is not None:
            try:
                # Casting l_obj.data to pyds.NvDsObjectMeta
                #obj_meta=pyds.glist_get_nvds_object_meta(l_obj.data)
                obj_meta=pyds.NvDsObjectMeta.cast(l_obj.data)
            except StopIteration:
                break
            obj_counter[obj_meta.class_id] += 1
#             print(f"Detected {pgie_classes_str[obj_meta.class_id]}")
            obj_meta.rect_params.border_color.set(0.0, 0.0, 1.0, 0.0)
            try: 
                l_obj=l_obj.next
            except StopIteration:
                break

        # Acquiring a display meta object. The memory ownership remains in
        # the C code so downstream plugins can still access it. Otherwise
        # the garbage collector will claim it when this probe function exits.
        display_meta=pyds.nvds_acquire_display_meta_from_pool(batch_meta)
        display_meta.num_labels = 1
        py_nvosd_text_params = display_meta.text_params[0]
        # Setting display text to be shown on screen
        # Note that the pyds module allocates a buffer for the string, and the
        # memory will not be claimed by the garbage collector.
        # Reading the display_text field here will return the C address of the
        # allocated string. Use pyds.get_string() to get the string content.
        py_nvosd_text_params.display_text = "Frame Number={} Number of Objects={} Vehicle_count={} Person_count={}".format(frame_number, num_rects, obj_counter[PGIE_CLASS_ID_VEHICLE], obj_counter[PGIE_CLASS_ID_PERSON])

        # Now set the offsets where the string should appear
        py_nvosd_text_params.x_offset = 10
        py_nvosd_text_params.y_offset = 12

        # Font , font-color and font-size
        py_nvosd_text_params.font_params.font_name = "Serif"
        py_nvosd_text_params.font_params.font_size = 10
        # set(red, green, blue, alpha); set to White
        py_nvosd_text_params.font_params.font_color.set(1.0, 1.0, 1.0, 1.0)

        # Text background color
        py_nvosd_text_params.set_bg_clr = 1
        # set(red, green, blue, alpha); set to Black
        py_nvosd_text_params.text_bg_clr.set(0.0, 0.0, 0.0, 1.0)
        # Using pyds.get_string() to get display_text as string
        print(pyds.get_string(py_nvosd_text_params.display_text))
        pyds.nvds_add_display_meta_to_frame(frame_meta, display_meta)
        try:
            l_frame=l_frame.next
        except StopIteration:
            break

    return Gst.PadProbeReturn.OK

# %%
# Standard GStreamer initialization
Gst.init(None)

# Create gstreamer elements
# Create Pipeline element that will form a connection of other elements
print("Creating Pipeline \n ")
pipeline = Gst.Pipeline()
if not pipeline:
        print(" Unable to create Pipeline \n")
# Out:
# Creating Pipeline

# %%
# Source element for reading from the file
print("Creating Source \n ")
source = Gst.ElementFactory.make("filesrc", "file-source")
if not source:
    print(" Unable to create Source \n")
# Out:
# Creating Source

# %%
# Since the data format in the input file is elementary h264 stream,
# we need a h264parser
print("Creating H264Parser \n")
h264parser = Gst.ElementFactory.make("h264parse", "h264-parser")
if not h264parser:
    print(" Unable to create h264 parser \n")
# Out:
# Creating H264Parser

# %%
# Use nvdec_h264 for hardware accelerated decode on GPU
print("Creating Decoder \n")
decoder = Gst.ElementFactory.make("nvv4l2decoder", "nvv4l2-decoder")
if not decoder:
    print(" Unable to create Nvv4l2 Decoder \n")
# Out:
# Creating Decoder

# %%
# Create nvstreammux instance to form batches from one or more sources.
print("Creating Muxer \n")
streammux = Gst.ElementFactory.make("nvstreammux", "Stream-muxer")
if not streammux:
    print(" Unable to create NvStreamMux \n")
# Out:
# Creating Muxer

# %%
# Use nvinfer to run inferencing on decoder's output,
# behaviour of inferencing is set through config file
print("Creating pgie")
pgie = Gst.ElementFactory.make("nvinfer", "primary-inference")
if not pgie:
    print(" Unable to create pgie \n")
# Out:
# Creating pgie

# %%
# Use convertor to convert from NV12 to RGBA as required by nvosd
print("Creating nvvidconv")
nvvidconv = Gst.ElementFactory.make("nvvideoconvert", "convertor")
if not nvvidconv:
    print(" Unable to create nvvidconv \n")
# Out:
# Creating nvvidconv

# %%
# Create OSD to draw on the converted RGBA buffer
print("Creating OSD")
nvosd = Gst.ElementFactory.make("nvdsosd", "onscreendisplay")
if not nvosd:
        print(" Unable to create nvosd \n")
# Out:
# Creating OSD

# %%
# Use convertor to convert from something to something
print("Creating encoder")
enc = Gst.ElementFactory.make("nvv4l2h264enc", "nvv4l2h264enc")
if not nvvidconv:
    print(" Unable to create nvvidconv \n")
    
# Use convertor to convert from something to something
print("Creating encoder")
converter2 = Gst.ElementFactory.make("nvvideoconvert", "converter2")
if not converter2:
    print(" Unable to create nvvidconv \n")

print("Creating File sink \n")
sink = Gst.ElementFactory.make("filesink", "filesink")
if not sink:
    print(" Unable to create file sink \n")

# print("Creating EGL sink \n")
# sink = Gst.ElementFactory.make("nveglglessink", "nvvideo-renderer")
# if not sink:
#     print(" Unable to create egl sink \n")

# print("Creating fake sink \n")
# sink = Gst.ElementFactory.make("fakesink", "nvvideo-renderer")
# if not sink:
#     print(" Unable to create fake sink \n")
# Out:
# Creating encoder
# Creating encoder
# Creating File sink

# %%
print("Playing file %s " %args[1])
source.set_property('location', args[1])
sink.set_property("location", args[2])
streammux.set_property('width', 1920)
streammux.set_property('height', 1080)
streammux.set_property('batch-size', 1)
streammux.set_property('batched-push-timeout', 4000000)
pgie.set_property('config-file-path', "/home/mher/projects/counter/deepstream-analytics/dsnvanalytics_pgie_config.txt")


print("Adding elements to Pipeline \n")
pipeline.add(source)
pipeline.add(h264parser)
pipeline.add(decoder)
pipeline.add(streammux)
pipeline.add(pgie)
pipeline.add(nvvidconv)
pipeline.add(nvosd)
pipeline.add(converter2)
pipeline.add(enc)
pipeline.add(sink)
# if is_aarch64():
#     pipeline.add(transform)
# Out:
# Playing file /opt/nvidia/deepstream/deepstream-6.1/samples/streams/sample_qHD.h264
# Adding elements to Pipeline
# True

# %%
# we link the elements together
# file-source -> h264-parser -> nvh264-decoder ->
# nvinfer -> nvvidconv -> nvosd -> video-renderer
print("Linking elements in the Pipeline \n")

source.link(h264parser)
h264parser.link(decoder)

sinkpad = streammux.get_request_pad("sink_0")
if not sinkpad:
    print(" Unable to get the sink pad of streammux \n")
    
srcpad = decoder.get_static_pad("src")
if not srcpad:
    print(" Unable to get source pad of decoder \n")
    
srcpad.link(sinkpad)
streammux.link(pgie)
pgie.link(nvvidconv)
nvvidconv.link(nvosd)
nvosd.link(converter2)
converter2.link(enc)
enc.link(sink)
# Out:
# Linking elements in the Pipeline
# True

# %%
# create an event loop and feed gstreamer bus mesages to it
loop = GLib.MainLoop()
bus = pipeline.get_bus()
bus.add_signal_watch()
bus.connect("message", bus_call, loop)
# Out:
# 1

# %%
# Lets add probe to get informed of the meta data generated, we add probe to
# the sink pad of the osd element, since by that time, the buffer would have
# had got all the metadata.
osdsinkpad = nvosd.get_static_pad("sink")
if not osdsinkpad:
    print(" Unable to get sink pad of nvosd \n")

osdsinkpad.add_probe(Gst.PadProbeType.BUFFER, osd_sink_pad_buffer_probe, 0)
# Out:
# 1

# %%
# start play back and listen to events
print("Starting pipeline \n")
to_play = pipeline.set_state(Gst.State.PLAYING)

try:
    loop.run()
except Exception as e:
    print(e)
    
# cleanup
pipeline.set_state(Gst.State.NULL)
# Out:
# Starting pipeline
#
# Frame Number=0 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=1 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=2 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=3 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=4 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=5 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=6 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=7 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=8 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=9 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=10 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=11 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=12 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=13 Number of Objects=8 Vehicle_count=2 Person_count=5
# Frame Number=14 Number of Objects=7 Vehicle_count=2 Person_count=4
# Frame Number=15 Number of Objects=7 Vehicle_count=1 Person_count=4
# Frame Number=16 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=17 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=18 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=19 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=20 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=21 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=22 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=23 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=24 Number of Objects=9 Vehicle_count=4 Person_count=3
# Frame Number=25 Number of Objects=7 Vehicle_count=2 Person_count=3
# Frame Number=26 Number of Objects=6 Vehicle_count=1 Person_count=3
# Frame Number=27 Number of Objects=6 Vehicle_count=1 Person_count=3
# Frame Number=28 Number of Objects=6 Vehicle_count=1 Person_count=3
# Frame Number=29 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=30 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=31 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=32 Number of Objects=6 Vehicle_count=1 Person_count=3
# Frame Number=33 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=34 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=35 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=36 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=37 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=38 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=39 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=40 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=41 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=42 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=43 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=44 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=45 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=46 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=47 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=48 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=49 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=50 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=51 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=52 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=53 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=54 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=55 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=56 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=57 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=58 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=59 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=60 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=61 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=62 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=63 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=64 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=65 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=66 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=67 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=68 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=69 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=70 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=71 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=72 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=73 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=74 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=75 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=76 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=77 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=78 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=79 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=80 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=81 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=82 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=83 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=84 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=85 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=86 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=87 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=88 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=89 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=90 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=91 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=92 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=93 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=94 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=95 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=96 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=97 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=98 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=99 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=100 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=101 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=102 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=103 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=104 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=105 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=106 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=107 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=108 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=109 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=110 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=111 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=112 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=113 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=114 Number of Objects=3 Vehicle_count=0 Person_count=3
# Frame Number=115 Number of Objects=3 Vehicle_count=0 Person_count=3
# Frame Number=116 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=117 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=118 Number of Objects=3 Vehicle_count=0 Person_count=3
# Frame Number=119 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=120 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=121 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=122 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=123 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=124 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=125 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=126 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=127 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=128 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=129 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=130 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=131 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=132 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=133 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=134 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=135 Number of Objects=3 Vehicle_count=0 Person_count=3
# Frame Number=136 Number of Objects=3 Vehicle_count=0 Person_count=3
# Frame Number=137 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=138 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=139 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=140 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=141 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=142 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=143 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=144 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=145 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=146 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=147 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=148 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=149 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=150 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=151 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=152 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=153 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=154 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=155 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=156 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=157 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=158 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=159 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=160 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=161 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=162 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=163 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=164 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=165 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=166 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=167 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=168 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=169 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=170 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=171 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=172 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=173 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=174 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=175 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=176 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=177 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=178 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=179 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=180 Number of Objects=5 Vehicle_count=2 Person_count=3
# Frame Number=181 Number of Objects=3 Vehicle_count=0 Person_count=3
# Frame Number=182 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=183 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=184 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=185 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=186 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=187 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=188 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=189 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=190 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=191 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=192 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=193 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=194 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=195 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=196 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=197 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=198 Number of Objects=6 Vehicle_count=3 Person_count=3
# Frame Number=199 Number of Objects=6 Vehicle_count=3 Person_count=3
# Frame Number=200 Number of Objects=8 Vehicle_count=5 Person_count=3
# Frame Number=201 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=202 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=203 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=204 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=205 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=206 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=207 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=208 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=209 Number of Objects=3 Vehicle_count=0 Person_count=3
# Frame Number=210 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=211 Number of Objects=7 Vehicle_count=3 Person_count=4
# Frame Number=212 Number of Objects=6 Vehicle_count=3 Person_count=3
# Frame Number=213 Number of Objects=9 Vehicle_count=5 Person_count=4
# Frame Number=214 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=215 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=216 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=217 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=218 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=219 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=220 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=221 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=222 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=223 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=224 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=225 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=226 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=227 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=228 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=229 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=230 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=231 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=232 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=233 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=234 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=235 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=236 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=237 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=238 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=239 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=240 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=241 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=242 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=243 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=244 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=245 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=246 Number of Objects=7 Vehicle_count=3 Person_count=4
# Frame Number=247 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=248 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=249 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=250 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=251 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=252 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=253 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=254 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=255 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=256 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=257 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=258 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=259 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=260 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=261 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=262 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=263 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=264 Number of Objects=7 Vehicle_count=2 Person_count=4
# Frame Number=265 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=266 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=267 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=268 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=269 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=270 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=271 Number of Objects=8 Vehicle_count=4 Person_count=4
# Frame Number=272 Number of Objects=9 Vehicle_count=5 Person_count=4
# Frame Number=273 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=274 Number of Objects=7 Vehicle_count=3 Person_count=4
# Frame Number=275 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=276 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=277 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=278 Number of Objects=8 Vehicle_count=3 Person_count=4
# Frame Number=279 Number of Objects=7 Vehicle_count=2 Person_count=4
# Frame Number=280 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=281 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=282 Number of Objects=7 Vehicle_count=4 Person_count=3
# Frame Number=283 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=284 Number of Objects=7 Vehicle_count=3 Person_count=3
# Frame Number=285 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=286 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=287 Number of Objects=6 Vehicle_count=3 Person_count=3
# Frame Number=288 Number of Objects=6 Vehicle_count=3 Person_count=3
# Frame Number=289 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=290 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=291 Number of Objects=7 Vehicle_count=2 Person_count=4
# Frame Number=292 Number of Objects=6 Vehicle_count=2 Person_count=4
# Frame Number=293 Number of Objects=9 Vehicle_count=2 Person_count=3
# Frame Number=294 Number of Objects=7 Vehicle_count=2 Person_count=3
# Frame Number=295 Number of Objects=5 Vehicle_count=1 Person_count=3
# Frame Number=296 Number of Objects=6 Vehicle_count=1 Person_count=3
# Frame Number=297 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=298 Number of Objects=7 Vehicle_count=2 Person_count=4
# Frame Number=299 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=300 Number of Objects=7 Vehicle_count=2 Person_count=4
# Frame Number=301 Number of Objects=8 Vehicle_count=3 Person_count=4
# Frame Number=302 Number of Objects=8 Vehicle_count=2 Person_count=4
# Frame Number=303 Number of Objects=8 Vehicle_count=2 Person_count=4
# Frame Number=304 Number of Objects=9 Vehicle_count=2 Person_count=5
# Frame Number=305 Number of Objects=9 Vehicle_count=3 Person_count=4
# Frame Number=306 Number of Objects=7 Vehicle_count=3 Person_count=4
# Frame Number=307 Number of Objects=7 Vehicle_count=3 Person_count=4
# Frame Number=308 Number of Objects=10 Vehicle_count=5 Person_count=4
# Frame Number=309 Number of Objects=9 Vehicle_count=5 Person_count=4
# Frame Number=310 Number of Objects=8 Vehicle_count=4 Person_count=4
# Frame Number=311 Number of Objects=8 Vehicle_count=4 Person_count=4
# Frame Number=312 Number of Objects=8 Vehicle_count=4 Person_count=4
# Frame Number=313 Number of Objects=8 Vehicle_count=4 Person_count=4
# Frame Number=314 Number of Objects=11 Vehicle_count=5 Person_count=6
# Frame Number=315 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=316 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=317 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=318 Number of Objects=12 Vehicle_count=6 Person_count=6
# Frame Number=319 Number of Objects=12 Vehicle_count=5 Person_count=7
# Frame Number=320 Number of Objects=12 Vehicle_count=6 Person_count=6
# Frame Number=321 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=322 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=323 Number of Objects=12 Vehicle_count=6 Person_count=6
# Frame Number=324 Number of Objects=11 Vehicle_count=5 Person_count=6
# Frame Number=325 Number of Objects=13 Vehicle_count=6 Person_count=6
# Frame Number=326 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=327 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=328 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=329 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=330 Number of Objects=10 Vehicle_count=3 Person_count=6
# Frame Number=331 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=332 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=333 Number of Objects=11 Vehicle_count=3 Person_count=7
# Frame Number=334 Number of Objects=12 Vehicle_count=3 Person_count=9
# Frame Number=335 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=336 Number of Objects=10 Vehicle_count=2 Person_count=8
# Frame Number=337 Number of Objects=11 Vehicle_count=2 Person_count=9
# Frame Number=338 Number of Objects=10 Vehicle_count=3 Person_count=7
# Frame Number=339 Number of Objects=11 Vehicle_count=3 Person_count=7
# Frame Number=340 Number of Objects=11 Vehicle_count=3 Person_count=7
# Frame Number=341 Number of Objects=12 Vehicle_count=3 Person_count=8
# Frame Number=342 Number of Objects=11 Vehicle_count=2 Person_count=7
# Frame Number=343 Number of Objects=12 Vehicle_count=2 Person_count=8
# Frame Number=344 Number of Objects=13 Vehicle_count=2 Person_count=9
# Frame Number=345 Number of Objects=16 Vehicle_count=3 Person_count=9
# Frame Number=346 Number of Objects=11 Vehicle_count=0 Person_count=8
# Frame Number=347 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=348 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=349 Number of Objects=13 Vehicle_count=2 Person_count=8
# Frame Number=350 Number of Objects=12 Vehicle_count=1 Person_count=9
# Frame Number=351 Number of Objects=14 Vehicle_count=2 Person_count=10
# Frame Number=352 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=353 Number of Objects=16 Vehicle_count=2 Person_count=11
# Frame Number=354 Number of Objects=15 Vehicle_count=1 Person_count=11
# Frame Number=355 Number of Objects=14 Vehicle_count=1 Person_count=12
# Frame Number=356 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=357 Number of Objects=13 Vehicle_count=1 Person_count=12
# Frame Number=358 Number of Objects=11 Vehicle_count=1 Person_count=10
# Frame Number=359 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=360 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=361 Number of Objects=10 Vehicle_count=0 Person_count=8
# Frame Number=362 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=363 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=364 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=365 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=366 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=367 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=368 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=369 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=370 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=371 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=372 Number of Objects=9 Vehicle_count=0 Person_count=8
# Frame Number=373 Number of Objects=9 Vehicle_count=0 Person_count=6
# Frame Number=374 Number of Objects=11 Vehicle_count=0 Person_count=8
# Frame Number=375 Number of Objects=14 Vehicle_count=0 Person_count=9
# Frame Number=376 Number of Objects=14 Vehicle_count=0 Person_count=8
# Frame Number=377 Number of Objects=15 Vehicle_count=0 Person_count=9
# Frame Number=378 Number of Objects=18 Vehicle_count=0 Person_count=12
# Frame Number=379 Number of Objects=12 Vehicle_count=0 Person_count=9
# Frame Number=380 Number of Objects=18 Vehicle_count=1 Person_count=9
# Frame Number=381 Number of Objects=12 Vehicle_count=2 Person_count=7
# Frame Number=382 Number of Objects=13 Vehicle_count=2 Person_count=7
# Frame Number=383 Number of Objects=9 Vehicle_count=0 Person_count=8
# Frame Number=384 Number of Objects=9 Vehicle_count=0 Person_count=8
# Frame Number=385 Number of Objects=9 Vehicle_count=0 Person_count=8
# Frame Number=386 Number of Objects=9 Vehicle_count=0 Person_count=8
# Frame Number=387 Number of Objects=10 Vehicle_count=0 Person_count=9
# Frame Number=388 Number of Objects=10 Vehicle_count=2 Person_count=6
# Frame Number=389 Number of Objects=8 Vehicle_count=0 Person_count=6
# Frame Number=390 Number of Objects=9 Vehicle_count=0 Person_count=6
# Frame Number=391 Number of Objects=8 Vehicle_count=1 Person_count=5
# Frame Number=392 Number of Objects=7 Vehicle_count=0 Person_count=5
# Frame Number=393 Number of Objects=9 Vehicle_count=2 Person_count=5
# Frame Number=394 Number of Objects=9 Vehicle_count=1 Person_count=4
# Frame Number=395 Number of Objects=7 Vehicle_count=0 Person_count=4
# Frame Number=396 Number of Objects=7 Vehicle_count=0 Person_count=5
# Frame Number=397 Number of Objects=7 Vehicle_count=1 Person_count=4
# Frame Number=398 Number of Objects=11 Vehicle_count=3 Person_count=6
# Frame Number=399 Number of Objects=9 Vehicle_count=3 Person_count=5
# Frame Number=400 Number of Objects=12 Vehicle_count=3 Person_count=6
# Frame Number=401 Number of Objects=13 Vehicle_count=2 Person_count=8
# Frame Number=402 Number of Objects=12 Vehicle_count=2 Person_count=6
# Frame Number=403 Number of Objects=15 Vehicle_count=2 Person_count=7
# Frame Number=404 Number of Objects=11 Vehicle_count=0 Person_count=8
# Frame Number=405 Number of Objects=10 Vehicle_count=0 Person_count=7
# Frame Number=406 Number of Objects=12 Vehicle_count=0 Person_count=8
# Frame Number=407 Number of Objects=12 Vehicle_count=0 Person_count=9
# Frame Number=408 Number of Objects=10 Vehicle_count=0 Person_count=7
# Frame Number=409 Number of Objects=11 Vehicle_count=0 Person_count=6
# Frame Number=410 Number of Objects=7 Vehicle_count=0 Person_count=5
# Frame Number=411 Number of Objects=9 Vehicle_count=0 Person_count=6
# Frame Number=412 Number of Objects=11 Vehicle_count=0 Person_count=6
# Frame Number=413 Number of Objects=12 Vehicle_count=0 Person_count=7
# Frame Number=414 Number of Objects=13 Vehicle_count=0 Person_count=7
# Frame Number=415 Number of Objects=14 Vehicle_count=1 Person_count=11
# Frame Number=416 Number of Objects=13 Vehicle_count=0 Person_count=9
# Frame Number=417 Number of Objects=12 Vehicle_count=0 Person_count=8
# Frame Number=418 Number of Objects=8 Vehicle_count=0 Person_count=6
# Frame Number=419 Number of Objects=10 Vehicle_count=0 Person_count=6
# Frame Number=420 Number of Objects=7 Vehicle_count=0 Person_count=5
# Frame Number=421 Number of Objects=11 Vehicle_count=0 Person_count=6
# Frame Number=422 Number of Objects=9 Vehicle_count=0 Person_count=5
# Frame Number=423 Number of Objects=11 Vehicle_count=0 Person_count=7
# Frame Number=424 Number of Objects=9 Vehicle_count=0 Person_count=6
# Frame Number=425 Number of Objects=10 Vehicle_count=0 Person_count=7
# Frame Number=426 Number of Objects=12 Vehicle_count=0 Person_count=7
# Frame Number=427 Number of Objects=12 Vehicle_count=0 Person_count=9
# Frame Number=428 Number of Objects=12 Vehicle_count=0 Person_count=8
# Frame Number=429 Number of Objects=8 Vehicle_count=0 Person_count=6
# Frame Number=430 Number of Objects=10 Vehicle_count=0 Person_count=7
# Frame Number=431 Number of Objects=9 Vehicle_count=0 Person_count=7
# Frame Number=432 Number of Objects=10 Vehicle_count=0 Person_count=5
# Frame Number=433 Number of Objects=5 Vehicle_count=0 Person_count=4
# Frame Number=434 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=435 Number of Objects=7 Vehicle_count=0 Person_count=5
# Frame Number=436 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=437 Number of Objects=5 Vehicle_count=0 Person_count=4
# Frame Number=438 Number of Objects=8 Vehicle_count=1 Person_count=6
# Frame Number=439 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=440 Number of Objects=13 Vehicle_count=0 Person_count=12
# Frame Number=441 Number of Objects=10 Vehicle_count=0 Person_count=9
# Frame Number=442 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=443 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=444 Number of Objects=10 Vehicle_count=2 Person_count=6
# Frame Number=445 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=446 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=447 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=448 Number of Objects=10 Vehicle_count=0 Person_count=10
# Frame Number=449 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=450 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=451 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=452 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=453 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=454 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=455 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=456 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=457 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=458 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=459 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=460 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=461 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=462 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=463 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=464 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=465 Number of Objects=5 Vehicle_count=1 Person_count=4
# Frame Number=466 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=467 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=468 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=469 Number of Objects=10 Vehicle_count=0 Person_count=10
# Frame Number=470 Number of Objects=13 Vehicle_count=1 Person_count=12
# Frame Number=471 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=472 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=473 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=474 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=475 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=476 Number of Objects=10 Vehicle_count=2 Person_count=8
# Frame Number=477 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=478 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=479 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=480 Number of Objects=7 Vehicle_count=1 Person_count=5
# Frame Number=481 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=482 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=483 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=484 Number of Objects=11 Vehicle_count=0 Person_count=8
# Frame Number=485 Number of Objects=8 Vehicle_count=0 Person_count=6
# Frame Number=486 Number of Objects=10 Vehicle_count=3 Person_count=7
# Frame Number=487 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=488 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=489 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=490 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=491 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=492 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=493 Number of Objects=10 Vehicle_count=0 Person_count=9
# Frame Number=494 Number of Objects=10 Vehicle_count=0 Person_count=9
# Frame Number=495 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=496 Number of Objects=10 Vehicle_count=0 Person_count=9
# Frame Number=497 Number of Objects=14 Vehicle_count=1 Person_count=9
# Frame Number=498 Number of Objects=12 Vehicle_count=1 Person_count=11
# Frame Number=499 Number of Objects=11 Vehicle_count=2 Person_count=9
# Frame Number=500 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=501 Number of Objects=12 Vehicle_count=2 Person_count=10
# Frame Number=502 Number of Objects=12 Vehicle_count=2 Person_count=10
# Frame Number=503 Number of Objects=11 Vehicle_count=2 Person_count=9
# Frame Number=504 Number of Objects=9 Vehicle_count=1 Person_count=7
# Frame Number=505 Number of Objects=9 Vehicle_count=1 Person_count=7
# Frame Number=506 Number of Objects=8 Vehicle_count=1 Person_count=6
# Frame Number=507 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=508 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=509 Number of Objects=11 Vehicle_count=2 Person_count=8
# Frame Number=510 Number of Objects=10 Vehicle_count=2 Person_count=8
# Frame Number=511 Number of Objects=11 Vehicle_count=2 Person_count=7
# Frame Number=512 Number of Objects=12 Vehicle_count=3 Person_count=6
# Frame Number=513 Number of Objects=9 Vehicle_count=2 Person_count=6
# Frame Number=514 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=515 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=516 Number of Objects=9 Vehicle_count=1 Person_count=7
# Frame Number=517 Number of Objects=13 Vehicle_count=3 Person_count=9
# Frame Number=518 Number of Objects=10 Vehicle_count=2 Person_count=7
# Frame Number=519 Number of Objects=14 Vehicle_count=2 Person_count=10
# Frame Number=520 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=521 Number of Objects=15 Vehicle_count=1 Person_count=12
# Frame Number=522 Number of Objects=14 Vehicle_count=0 Person_count=14
# Frame Number=523 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=524 Number of Objects=13 Vehicle_count=1 Person_count=8
# Frame Number=525 Number of Objects=12 Vehicle_count=2 Person_count=9
# Frame Number=526 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=527 Number of Objects=13 Vehicle_count=2 Person_count=10
# Frame Number=528 Number of Objects=11 Vehicle_count=1 Person_count=10
# Frame Number=529 Number of Objects=13 Vehicle_count=1 Person_count=9
# Frame Number=530 Number of Objects=11 Vehicle_count=2 Person_count=7
# Frame Number=531 Number of Objects=14 Vehicle_count=2 Person_count=10
# Frame Number=532 Number of Objects=10 Vehicle_count=1 Person_count=8
# Frame Number=533 Number of Objects=11 Vehicle_count=2 Person_count=8
# Frame Number=534 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=535 Number of Objects=10 Vehicle_count=3 Person_count=7
# Frame Number=536 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=537 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=538 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=539 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=540 Number of Objects=12 Vehicle_count=0 Person_count=11
# Frame Number=541 Number of Objects=11 Vehicle_count=0 Person_count=9
# Frame Number=542 Number of Objects=16 Vehicle_count=0 Person_count=14
# Frame Number=543 Number of Objects=14 Vehicle_count=1 Person_count=11
# Frame Number=544 Number of Objects=18 Vehicle_count=0 Person_count=15
# Frame Number=545 Number of Objects=9 Vehicle_count=0 Person_count=7
# Frame Number=546 Number of Objects=8 Vehicle_count=0 Person_count=6
# Frame Number=547 Number of Objects=13 Vehicle_count=0 Person_count=9
# Frame Number=548 Number of Objects=10 Vehicle_count=0 Person_count=8
# Frame Number=549 Number of Objects=8 Vehicle_count=0 Person_count=6
# Frame Number=550 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=551 Number of Objects=6 Vehicle_count=0 Person_count=5
# Frame Number=552 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=553 Number of Objects=6 Vehicle_count=0 Person_count=5
# Frame Number=554 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=555 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=556 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=557 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=558 Number of Objects=10 Vehicle_count=1 Person_count=7
# Frame Number=559 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=560 Number of Objects=13 Vehicle_count=4 Person_count=9
# Frame Number=561 Number of Objects=8 Vehicle_count=1 Person_count=6
# Frame Number=562 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=563 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=564 Number of Objects=8 Vehicle_count=1 Person_count=6
# Frame Number=565 Number of Objects=10 Vehicle_count=1 Person_count=7
# Frame Number=566 Number of Objects=7 Vehicle_count=1 Person_count=5
# Frame Number=567 Number of Objects=10 Vehicle_count=1 Person_count=7
# Frame Number=568 Number of Objects=9 Vehicle_count=1 Person_count=6
# Frame Number=569 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=570 Number of Objects=7 Vehicle_count=1 Person_count=6
# Frame Number=571 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=572 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=573 Number of Objects=11 Vehicle_count=1 Person_count=7
# Frame Number=574 Number of Objects=9 Vehicle_count=0 Person_count=6
# Frame Number=575 Number of Objects=12 Vehicle_count=4 Person_count=6
# Frame Number=576 Number of Objects=9 Vehicle_count=3 Person_count=4
# Frame Number=577 Number of Objects=6 Vehicle_count=0 Person_count=6
# Frame Number=578 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=579 Number of Objects=7 Vehicle_count=0 Person_count=5
# Frame Number=580 Number of Objects=9 Vehicle_count=0 Person_count=7
# Frame Number=581 Number of Objects=9 Vehicle_count=1 Person_count=7
# Frame Number=582 Number of Objects=8 Vehicle_count=1 Person_count=5
# Frame Number=583 Number of Objects=9 Vehicle_count=1 Person_count=7
# Frame Number=584 Number of Objects=9 Vehicle_count=2 Person_count=6
# Frame Number=585 Number of Objects=10 Vehicle_count=1 Person_count=8
# Frame Number=586 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=587 Number of Objects=10 Vehicle_count=1 Person_count=8
# Frame Number=588 Number of Objects=7 Vehicle_count=1 Person_count=5
# Frame Number=589 Number of Objects=7 Vehicle_count=1 Person_count=5
# Frame Number=590 Number of Objects=8 Vehicle_count=2 Person_count=5
# Frame Number=591 Number of Objects=8 Vehicle_count=1 Person_count=6
# Frame Number=592 Number of Objects=6 Vehicle_count=0 Person_count=5
# Frame Number=593 Number of Objects=10 Vehicle_count=1 Person_count=6
# Frame Number=594 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=595 Number of Objects=8 Vehicle_count=1 Person_count=6
# Frame Number=596 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=597 Number of Objects=7 Vehicle_count=1 Person_count=5
# Frame Number=598 Number of Objects=6 Vehicle_count=0 Person_count=5
# Frame Number=599 Number of Objects=9 Vehicle_count=2 Person_count=6
# Frame Number=600 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=601 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=602 Number of Objects=8 Vehicle_count=0 Person_count=7
# Frame Number=603 Number of Objects=7 Vehicle_count=0 Person_count=6
# Frame Number=604 Number of Objects=9 Vehicle_count=0 Person_count=6
# Frame Number=605 Number of Objects=6 Vehicle_count=0 Person_count=5
# Frame Number=606 Number of Objects=9 Vehicle_count=0 Person_count=7
# Frame Number=607 Number of Objects=8 Vehicle_count=0 Person_count=6
# Frame Number=608 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=609 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=610 Number of Objects=5 Vehicle_count=0 Person_count=5
# Frame Number=611 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=612 Number of Objects=5 Vehicle_count=0 Person_count=4
# Frame Number=613 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=614 Number of Objects=4 Vehicle_count=0 Person_count=4
# Frame Number=615 Number of Objects=5 Vehicle_count=0 Person_count=3
# Frame Number=616 Number of Objects=5 Vehicle_count=0 Person_count=3
# Frame Number=617 Number of Objects=5 Vehicle_count=0 Person_count=4
# Frame Number=618 Number of Objects=4 Vehicle_count=0 Person_count=3
# Frame Number=619 Number of Objects=4 Vehicle_count=0 Person_count=3
# Frame Number=620 Number of Objects=6 Vehicle_count=0 Person_count=3
# Frame Number=621 Number of Objects=5 Vehicle_count=0 Person_count=4
# Frame Number=622 Number of Objects=4 Vehicle_count=0 Person_count=3
# Frame Number=623 Number of Objects=5 Vehicle_count=0 Person_count=3
# Frame Number=624 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=625 Number of Objects=3 Vehicle_count=0 Person_count=3
# Frame Number=626 Number of Objects=3 Vehicle_count=0 Person_count=3
# Frame Number=627 Number of Objects=6 Vehicle_count=1 Person_count=3
# Frame Number=628 Number of Objects=4 Vehicle_count=1 Person_count=3
# Frame Number=629 Number of Objects=5 Vehicle_count=0 Person_count=3
# Frame Number=630 Number of Objects=5 Vehicle_count=0 Person_count=3
# Frame Number=631 Number of Objects=4 Vehicle_count=0 Person_count=3
# Frame Number=632 Number of Objects=4 Vehicle_count=0 Person_count=3
# Frame Number=633 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=634 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=635 Number of Objects=7 Vehicle_count=2 Person_count=3
# Frame Number=636 Number of Objects=6 Vehicle_count=2 Person_count=3
# Frame Number=637 Number of Objects=8 Vehicle_count=3 Person_count=4
# Frame Number=638 Number of Objects=12 Vehicle_count=4 Person_count=5
# Frame Number=639 Number of Objects=11 Vehicle_count=4 Person_count=5
# Frame Number=640 Number of Objects=10 Vehicle_count=1 Person_count=6
# Frame Number=641 Number of Objects=11 Vehicle_count=2 Person_count=5
# Frame Number=642 Number of Objects=16 Vehicle_count=2 Person_count=7
# Frame Number=643 Number of Objects=15 Vehicle_count=2 Person_count=8
# Frame Number=644 Number of Objects=13 Vehicle_count=2 Person_count=7
# Frame Number=645 Number of Objects=11 Vehicle_count=2 Person_count=6
# Frame Number=646 Number of Objects=10 Vehicle_count=2 Person_count=6
# Frame Number=647 Number of Objects=9 Vehicle_count=2 Person_count=5
# Frame Number=648 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=649 Number of Objects=8 Vehicle_count=1 Person_count=5
# Frame Number=650 Number of Objects=7 Vehicle_count=0 Person_count=4
# Frame Number=651 Number of Objects=8 Vehicle_count=1 Person_count=4
# Frame Number=652 Number of Objects=9 Vehicle_count=2 Person_count=4
# Frame Number=653 Number of Objects=8 Vehicle_count=2 Person_count=4
# Frame Number=654 Number of Objects=8 Vehicle_count=1 Person_count=4
# Frame Number=655 Number of Objects=10 Vehicle_count=1 Person_count=6
# Frame Number=656 Number of Objects=14 Vehicle_count=3 Person_count=6
# Frame Number=657 Number of Objects=10 Vehicle_count=3 Person_count=5
# Frame Number=658 Number of Objects=9 Vehicle_count=3 Person_count=5
# Frame Number=659 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=660 Number of Objects=10 Vehicle_count=3 Person_count=6
# Frame Number=661 Number of Objects=9 Vehicle_count=4 Person_count=5
# Frame Number=662 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=663 Number of Objects=9 Vehicle_count=2 Person_count=6
# Frame Number=664 Number of Objects=10 Vehicle_count=1 Person_count=7
# Frame Number=665 Number of Objects=10 Vehicle_count=2 Person_count=6
# Frame Number=666 Number of Objects=13 Vehicle_count=2 Person_count=8
# Frame Number=667 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=668 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=669 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=670 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=671 Number of Objects=6 Vehicle_count=1 Person_count=4
# Frame Number=672 Number of Objects=8 Vehicle_count=1 Person_count=5
# Frame Number=673 Number of Objects=9 Vehicle_count=2 Person_count=6
# Frame Number=674 Number of Objects=10 Vehicle_count=2 Person_count=7
# Frame Number=675 Number of Objects=13 Vehicle_count=4 Person_count=8
# Frame Number=676 Number of Objects=14 Vehicle_count=4 Person_count=8
# Frame Number=677 Number of Objects=13 Vehicle_count=4 Person_count=8
# Frame Number=678 Number of Objects=10 Vehicle_count=1 Person_count=8
# Frame Number=679 Number of Objects=9 Vehicle_count=2 Person_count=6
# Frame Number=680 Number of Objects=10 Vehicle_count=1 Person_count=8
# Frame Number=681 Number of Objects=10 Vehicle_count=1 Person_count=8
# Frame Number=682 Number of Objects=13 Vehicle_count=2 Person_count=9
# Frame Number=683 Number of Objects=12 Vehicle_count=3 Person_count=7
# Frame Number=684 Number of Objects=12 Vehicle_count=3 Person_count=8
# Frame Number=685 Number of Objects=12 Vehicle_count=4 Person_count=7
# Frame Number=686 Number of Objects=11 Vehicle_count=3 Person_count=7
# Frame Number=687 Number of Objects=12 Vehicle_count=3 Person_count=8
# Frame Number=688 Number of Objects=11 Vehicle_count=3 Person_count=7
# Frame Number=689 Number of Objects=10 Vehicle_count=2 Person_count=7
# Frame Number=690 Number of Objects=12 Vehicle_count=2 Person_count=9
# Frame Number=691 Number of Objects=13 Vehicle_count=3 Person_count=9
# Frame Number=692 Number of Objects=12 Vehicle_count=3 Person_count=8
# Frame Number=693 Number of Objects=12 Vehicle_count=3 Person_count=8
# Frame Number=694 Number of Objects=11 Vehicle_count=2 Person_count=8
# Frame Number=695 Number of Objects=12 Vehicle_count=3 Person_count=8
# Frame Number=696 Number of Objects=13 Vehicle_count=4 Person_count=8
# Frame Number=697 Number of Objects=12 Vehicle_count=3 Person_count=8
# Frame Number=698 Number of Objects=14 Vehicle_count=5 Person_count=8
# Frame Number=699 Number of Objects=14 Vehicle_count=3 Person_count=9
# Frame Number=700 Number of Objects=13 Vehicle_count=5 Person_count=7
# Frame Number=701 Number of Objects=12 Vehicle_count=4 Person_count=8
# Frame Number=702 Number of Objects=11 Vehicle_count=4 Person_count=6
# ...
# Frame Number=1574 Number of Objects=13 Vehicle_count=6 Person_count=7
# Frame Number=1575 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=1576 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=1577 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=1578 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=1579 Number of Objects=9 Vehicle_count=4 Person_count=5
# Frame Number=1580 Number of Objects=11 Vehicle_count=6 Person_count=5
# Frame Number=1581 Number of Objects=9 Vehicle_count=4 Person_count=5
# Frame Number=1582 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=1583 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=1584 Number of Objects=11 Vehicle_count=6 Person_count=5
# Frame Number=1585 Number of Objects=9 Vehicle_count=4 Person_count=5
# Frame Number=1586 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=1587 Number of Objects=9 Vehicle_count=5 Person_count=4
# Frame Number=1588 Number of Objects=11 Vehicle_count=7 Person_count=4
# Frame Number=1589 Number of Objects=9 Vehicle_count=5 Person_count=4
# Frame Number=1590 Number of Objects=11 Vehicle_count=7 Person_count=4
# Frame Number=1591 Number of Objects=10 Vehicle_count=6 Person_count=4
# Frame Number=1592 Number of Objects=12 Vehicle_count=7 Person_count=5
# Frame Number=1593 Number of Objects=12 Vehicle_count=6 Person_count=6
# Frame Number=1594 Number of Objects=11 Vehicle_count=6 Person_count=5
# Frame Number=1595 Number of Objects=8 Vehicle_count=4 Person_count=4
# Frame Number=1596 Number of Objects=9 Vehicle_count=5 Person_count=4
# Frame Number=1597 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=1598 Number of Objects=9 Vehicle_count=4 Person_count=5
# Frame Number=1599 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=1600 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=1601 Number of Objects=11 Vehicle_count=5 Person_count=6
# Frame Number=1602 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=1603 Number of Objects=9 Vehicle_count=4 Person_count=5
# Frame Number=1604 Number of Objects=13 Vehicle_count=5 Person_count=8
# Frame Number=1605 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1606 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1607 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1608 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1609 Number of Objects=10 Vehicle_count=3 Person_count=7
# Frame Number=1610 Number of Objects=10 Vehicle_count=3 Person_count=7
# Frame Number=1611 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=1612 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=1613 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=1614 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=1615 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1616 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=1617 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=1618 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=1619 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=1620 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1621 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=1622 Number of Objects=12 Vehicle_count=4 Person_count=8
# Frame Number=1623 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=1624 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=1625 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=1626 Number of Objects=6 Vehicle_count=1 Person_count=5
# Frame Number=1627 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=1628 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=1629 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=1630 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=1631 Number of Objects=7 Vehicle_count=2 Person_count=5
# Frame Number=1632 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1633 Number of Objects=11 Vehicle_count=5 Person_count=6
# Frame Number=1634 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=1635 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1636 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1637 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1638 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1639 Number of Objects=11 Vehicle_count=5 Person_count=6
# Frame Number=1640 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=1641 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1642 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1643 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=1644 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=1645 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1646 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1647 Number of Objects=10 Vehicle_count=5 Person_count=5
# Frame Number=1648 Number of Objects=10 Vehicle_count=3 Person_count=7
# Frame Number=1649 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1650 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=1651 Number of Objects=10 Vehicle_count=3 Person_count=7
# Frame Number=1652 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1653 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=1654 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=1655 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=1656 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=1657 Number of Objects=8 Vehicle_count=3 Person_count=5
# Frame Number=1658 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1659 Number of Objects=11 Vehicle_count=5 Person_count=6
# Frame Number=1660 Number of Objects=9 Vehicle_count=3 Person_count=6
# Frame Number=1661 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=1662 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1663 Number of Objects=10 Vehicle_count=4 Person_count=6
# Frame Number=1664 Number of Objects=8 Vehicle_count=2 Person_count=6
# Frame Number=1665 Number of Objects=10 Vehicle_count=2 Person_count=8
# Frame Number=1666 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=1667 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1668 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1669 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1670 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1671 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1672 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=1673 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=1674 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1675 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1676 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1677 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=1678 Number of Objects=7 Vehicle_count=0 Person_count=7
# Frame Number=1679 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1680 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=1681 Number of Objects=11 Vehicle_count=2 Person_count=9
# Frame Number=1682 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1683 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1684 Number of Objects=12 Vehicle_count=3 Person_count=9
# Frame Number=1685 Number of Objects=10 Vehicle_count=2 Person_count=8
# Frame Number=1686 Number of Objects=11 Vehicle_count=3 Person_count=8
# Frame Number=1687 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=1688 Number of Objects=12 Vehicle_count=3 Person_count=9
# Frame Number=1689 Number of Objects=12 Vehicle_count=3 Person_count=9
# Frame Number=1690 Number of Objects=13 Vehicle_count=4 Person_count=9
# Frame Number=1691 Number of Objects=14 Vehicle_count=4 Person_count=10
# Frame Number=1692 Number of Objects=13 Vehicle_count=4 Person_count=9
# Frame Number=1693 Number of Objects=13 Vehicle_count=4 Person_count=9
# Frame Number=1694 Number of Objects=11 Vehicle_count=2 Person_count=9
# Frame Number=1695 Number of Objects=10 Vehicle_count=3 Person_count=7
# Frame Number=1696 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=1697 Number of Objects=11 Vehicle_count=3 Person_count=8
# Frame Number=1698 Number of Objects=11 Vehicle_count=4 Person_count=7
# Frame Number=1699 Number of Objects=10 Vehicle_count=2 Person_count=8
# Frame Number=1700 Number of Objects=9 Vehicle_count=2 Person_count=7
# Frame Number=1701 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=1702 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=1703 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=1704 Number of Objects=13 Vehicle_count=3 Person_count=10
# Frame Number=1705 Number of Objects=11 Vehicle_count=2 Person_count=9
# Frame Number=1706 Number of Objects=12 Vehicle_count=2 Person_count=10
# Frame Number=1707 Number of Objects=12 Vehicle_count=3 Person_count=9
# Frame Number=1708 Number of Objects=11 Vehicle_count=2 Person_count=9
# Frame Number=1709 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1710 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1711 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1712 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1713 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1714 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1715 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1716 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1717 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1718 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1719 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1720 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1721 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1722 Number of Objects=11 Vehicle_count=0 Person_count=11
# Frame Number=1723 Number of Objects=11 Vehicle_count=0 Person_count=11
# Frame Number=1724 Number of Objects=10 Vehicle_count=0 Person_count=10
# Frame Number=1725 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1726 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1727 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1728 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1729 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1730 Number of Objects=11 Vehicle_count=0 Person_count=11
# Frame Number=1731 Number of Objects=11 Vehicle_count=0 Person_count=11
# Frame Number=1732 Number of Objects=12 Vehicle_count=0 Person_count=12
# Frame Number=1733 Number of Objects=11 Vehicle_count=0 Person_count=11
# Frame Number=1734 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1735 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1736 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1737 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1738 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1739 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1740 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1741 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1742 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1743 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1744 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1745 Number of Objects=8 Vehicle_count=0 Person_count=8
# Frame Number=1746 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1747 Number of Objects=9 Vehicle_count=0 Person_count=9
# Frame Number=1748 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=1749 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=1750 Number of Objects=10 Vehicle_count=2 Person_count=8
# Frame Number=1751 Number of Objects=11 Vehicle_count=1 Person_count=10
# Frame Number=1752 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=1753 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=1754 Number of Objects=8 Vehicle_count=1 Person_count=7
# Frame Number=1755 Number of Objects=12 Vehicle_count=1 Person_count=11
# Frame Number=1756 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=1757 Number of Objects=10 Vehicle_count=2 Person_count=8
# Frame Number=1758 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=1759 Number of Objects=11 Vehicle_count=1 Person_count=10
# Frame Number=1760 Number of Objects=11 Vehicle_count=2 Person_count=9
# Frame Number=1761 Number of Objects=12 Vehicle_count=3 Person_count=8
# Frame Number=1762 Number of Objects=12 Vehicle_count=2 Person_count=9
# Frame Number=1763 Number of Objects=9 Vehicle_count=1 Person_count=8
# Frame Number=1764 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=1765 Number of Objects=10 Vehicle_count=1 Person_count=9
# Frame Number=1766 Number of Objects=12 Vehicle_count=1 Person_count=9
# Frame Number=1767 Number of Objects=14 Vehicle_count=2 Person_count=9
# Frame Number=1768 Number of Objects=14 Vehicle_count=1 Person_count=10
# Frame Number=1769 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=1770 Number of Objects=12 Vehicle_count=2 Person_count=9
# Frame Number=1771 Number of Objects=14 Vehicle_count=3 Person_count=10
# Frame Number=1772 Number of Objects=13 Vehicle_count=2 Person_count=10
# Frame Number=1773 Number of Objects=13 Vehicle_count=1 Person_count=11
# Frame Number=1774 Number of Objects=14 Vehicle_count=1 Person_count=10
# Frame Number=1775 Number of Objects=15 Vehicle_count=3 Person_count=11
# Frame Number=1776 Number of Objects=14 Vehicle_count=1 Person_count=12
# Frame Number=1777 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=1778 Number of Objects=13 Vehicle_count=1 Person_count=11
# Frame Number=1779 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=1780 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=1781 Number of Objects=13 Vehicle_count=2 Person_count=9
# Frame Number=1782 Number of Objects=12 Vehicle_count=2 Person_count=9
# Frame Number=1783 Number of Objects=10 Vehicle_count=1 Person_count=8
# Frame Number=1784 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=1785 Number of Objects=11 Vehicle_count=2 Person_count=7
# Frame Number=1786 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=1787 Number of Objects=16 Vehicle_count=3 Person_count=12
# Frame Number=1788 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=1789 Number of Objects=13 Vehicle_count=2 Person_count=10
# Frame Number=1790 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=1791 Number of Objects=12 Vehicle_count=1 Person_count=10
# Frame Number=1792 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=1793 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=1794 Number of Objects=11 Vehicle_count=1 Person_count=9
# Frame Number=1795 Number of Objects=10 Vehicle_count=1 Person_count=8
# Frame Number=1796 Number of Objects=9 Vehicle_count=0 Person_count=8
# Frame Number=1797 Number of Objects=11 Vehicle_count=0 Person_count=10
# Frame Number=1798 Number of Objects=11 Vehicle_count=0 Person_count=10
# Frame Number=1799 Number of Objects=11 Vehicle_count=0 Person_count=10
# Frame Number=1800 Number of Objects=10 Vehicle_count=0 Person_count=9
# Frame Number=1801 Number of Objects=10 Vehicle_count=0 Person_count=9
# End-of-stream
# <enum GST_STATE_CHANGE_SUCCESS of type Gst.StateChangeReturn>

# %%
# from os.path import exists

# file_exists = exists(path_to_file)

# dir(pipeline)
pipeline.get_state(3)
# Out:
# (<enum GST_STATE_CHANGE_SUCCESS of type Gst.StateChangeReturn>, state=<enum GST_STATE_NULL of type Gst.State>, pending=<enum GST_STATE_VOID_PENDING of type Gst.State>)

# %%
for i in range(pipeline.get_children_count()):
    print(pipeline.get_child_by_index(i))
# Out:
# <__gi__.GstFileSink object at 0x7fc973b47b40 (GstFileSink at 0x33ed1f0)>
# <__gi__.nvv4l2h264enc object at 0x7fc973b47640 (nvv4l2h264enc at 0x33e67d0)>
# <__gi__.Gstnvvideoconvert object at 0x7fc973b41900 (Gstnvvideoconvert at 0x33ea480)>
# <__gi__.GstNvDsOsd object at 0x7fc973b41a00 (GstNvDsOsd at 0x3333f60)>
# <__gi__.Gstnvvideoconvert object at 0x7fc973b41380 (Gstnvvideoconvert at 0x32f0a60)>
# <__gi__.GstNvInfer object at 0x7fc973b3bd80 (GstNvInfer at 0x32ea440)>
# <__gi__.GstNvStreamMux object at 0x7fc973b3b600 (GstNvStreamMux at 0x275c160)>
# <__gi__.nvv4l2decoder object at 0x7fc973b3b140 (nvv4l2decoder at 0x264cbe0)>
# <__gi__.GstH264Parse object at 0x7fc973b31b40 (GstH264Parse at 0x2642170)>
# <__gi__.GstFileSrc object at 0x7fc973b31580 (GstFileSrc at 0x263a170)>

# %%
pipeline.find_unlinked_pad(Gst.PadDirection.SINK)

# %%
itrr = pipeline.iterate_elements()

status, el = itrr.next()
while status == Gst.IteratorResult.OK:
    print(el)
    status, el = itrr.next()
# Out:
# <__gi__.GstFileSink object at 0x7fc973b47b40 (GstFileSink at 0x33ed1f0)>
# <__gi__.nvv4l2h264enc object at 0x7fc973b47640 (nvv4l2h264enc at 0x33e67d0)>
# <__gi__.Gstnvvideoconvert object at 0x7fc973b41900 (Gstnvvideoconvert at 0x33ea480)>
# <__gi__.GstNvDsOsd object at 0x7fc973b41a00 (GstNvDsOsd at 0x3333f60)>
# <__gi__.Gstnvvideoconvert object at 0x7fc973b41380 (Gstnvvideoconvert at 0x32f0a60)>
# <__gi__.GstNvInfer object at 0x7fc973b3bd80 (GstNvInfer at 0x32ea440)>
# <__gi__.GstNvStreamMux object at 0x7fc973b3b600 (GstNvStreamMux at 0x275c160)>
# <__gi__.nvv4l2decoder object at 0x7fc973b3b140 (nvv4l2decoder at 0x264cbe0)>
# <__gi__.GstH264Parse object at 0x7fc973b31b40 (GstH264Parse at 0x2642170)>
# <__gi__.GstFileSrc object at 0x7fc973b31580 (GstFileSrc at 0x263a170)>
