# %% [markdown]
# <h1><center>American University of Armenia</center></h1>
# <h2><center>Time Series Forecasting</center></h2>
# <h3><center>Instructor: Aram Butavyan</center></h3>
# <h3><center>Team Members: Artur Avagyan, Armine Khachatryan, Mher Movsisyan, Hrach Yeghiazaryan</center></h3>
# <h3><center>Topic: Oil price Prediction</center></h3>

# %% [markdown]
# #### _Retrieved from Hrach Yeghiazaryan’s Individual Project Proposal_

# %% [markdown]
# ### Table of Contents
#
# * [Problem definition and suggested approaches](#def)
# * [Use cases](#use)
# * [Detailed data description](#description)
# * [Literature review](#lit)
# * [SARIMA](#sarima)
# * [Holt Winter's](#hw)
# * [GARCH](#garch)

# %% [markdown]
# ### <b>Problem definition and suggested approaches<a id="def"></a><b>

# %% [markdown]
# #### My individual proposal is, given the oil price time series up to a time point apply time series forecasting methods to predict its price in the upcoming time periods. The methods will mostly be related to machine learning and deep learning, in particular, it is expected that a recurrent neural networks will achieve good performance. Though it is also worth to try simple approaches such as autoregression model.

# %% [markdown]
# ### <b>Use cases<a id="use"></a><b>

# %% [markdown]
# #### Nowadays people are naturally very interested in the oil price, as it is a product that most of the people unavoidably have to use. That is why the prediction of oil price that will give people some sense about the expenses they are going to have in the future is a very useful problem to solve. Also, there are people that are trading stocks in the oil industry and knowing the price of the oil in the future may be of central importance in building trading strategies there. Moreover, oil is a natural resource that plays a huge role in the development of countries that possess that resource in high amounts have huge economic growth due to selling that oil on the neighboring countries, and that means that the prediction of oil price will be very interesting to such countries.

# %% [markdown]
# ### <b>Detailed data description<a id="description"></a><b>

# %% [markdown]
# #### The present data we have the work done on for this milestone is a time series of crude oil price in the last 70 years. The data was retrieved from this <a href="https://www.macrotrends.net/1369/crude-oil-price-history-chart">link</a>. As the website didn’t let us download the data, we had to write all the data manually, and while doing that we noticed that in some places the price didn’t change for several months, especially in the beginning of the series when the data is about very old years like 1940-s, 1950-s and even 1960-s. We suspect that because that data is old, some points were missing, so a forward filling was applied.
# #### The three variables of the data are year, month and the price. The data visualizations can be found in ipynb file.
# #### In the future milestones we will also use time series that record the:
# <h5>
# <ul>
#     <li>U.S. Crude Oil Production</li>
#     <li>U.S. Crude Oil Exports</li>
#     <li>Saudi Arabia Crude Oil Production</li>
#     <li>U.S. Crude Oil Reserves</li>
#     <li>Natural Gas Prices</li>
#     <li>Gasoline Prices</li>
#     <li>Propane Prices</li>
# <ul>
# <h5>

# %% [markdown]
# ### <b>Literature Review<a id="lit"></a><b>
#
# <ol>
#     <h3>
#         <li>
#         Relationship between crude oil price and production levels - An empirical study of OPEC and non-OPEC states <a href="https://www.frontiersin.org/articles/10.3389/fenvs.2022.933431/full#h12">Link</a>
#         </li>
#     </h3>
#     <h4>
#         Through an empirical examination, the "Relationship between crude oil price and production levels - An empirical study of OPEC and non-OPEC states" paper, written in Frontiers in Environmental Science (2018, November), investigates the link between the price of crude oil and its output on the regions of the Organization of the Petroleum Exporting Countries (OPEC) and non-Organization of the Petroleum Exporting Countries (non-OPEC). The paper discusses that the price of crude oil has lately fluctuated so much that it is impossible to forecast it, which volatility affects the global economy by changing the cost of common basic materials. This research used the information to understand better the variables that impact the price of crude oil. For the examination, the researchers collected data from January 1995 to November 2015 from West Texas Intermediate (WTI), Brent, and Dubai oil prices for that period.
#         The paper is helpful, as it indicates how researchers dealt with the data, what research methods they used, and gives a reasonable analysis of the whole project. The abovementioned reasons will help us in our project's further steps and will help us examine the causes of crude oil price increases or decreases, the factors of such behavior, and its example will mainly help us make precise forecasting.
#     </h4>
#     <h3>
#         <li>
#         An analysis of crude oil prices in the last decade (2011-2020): With deep learning approach <a href="https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0268996#sec020">Link</a>
#         </li>
#     </h3>
#     <h4>
#         The paper "An analysis of crude oil prices in the last decade (2011-2020): With deep learning approach," written in the open-access journal "Plos One," tells the results of an examination of how crude oil inventories affect crude oil prices starting from 2011 to 2020. The study has been held using the relationship between inventory announcements and the price variation of crude oil. Moreover, several other financial instruments (for investigating how these instruments related to changes in crude oil prices) were added. To complete the work, the researchers used various mathematical tools, including machine learning techniques like Long Short Term Memory (LSTM) approaches.
#         This particular study will help us to conduct our research using Machine Learning and Deep Learning approaches, to understand the factors that cause crude oil price fluctuation and give a mathematical solution for exploring and predicting new values of the prices.
#     </h4>
# </ol>

# %% [markdown]
# ### Code base
#
# All the code base is properly documented in the file 'DataExplorationAndAnalisys_CrudeOil'. If you wish to run this notebook live, please run the cell below first which will run all the code in the mentioned file, needed to generate the visualizations.

# %%
import warnings
warnings.filterwarnings('ignore')

# %run DataExploration_CrudeOil.ipynb
# Out:
# All code ran successfully

# %%
plot_data()

# %% [markdown]
# #### The time series plot shows a clear trend, as well as seasonality. This suggests that the data has both a long-term underlying pattern as well as shorter-term fluctuations that are affected by specific factors or events. Understanding and accounting for both trends and seasonality is important for accurate analysis and forecasting of the data. It is also needed to do further analysis for non-stationarity of the data.

# %%
plot_price_seasonality()

# %%
plot_price_cycles()

# %%
plot_ACF_PACF()

# %% [markdown]
# #### After examining the ACF (autocorrelation function) and PACF (partial autocorrelation function) plots of the time series data, it is clear that the data is not stationary.The patterns of ACF and PACF plots suggest that the data has both trend and seasonality components that need to be accounted for in modeling and analysis. It is important to apply appropriate methods, such as differencing or seasonal adjustment, to make the data stationary before proceeding with further analysis.

# %% [markdown]
# ## <b>SARIMA<a id="sarima"></a><b>

# %%
first_diff()

# %%
plot_ACF_PACF_diff()

# %%
check_diff_data_stationarity()
# Out:
# ADF Statistic: -9.895198
# p-value: 0.000000
# Critical Values:
# 	1%: -3.438
# 	5%: -2.865
# 	10%: -2.568
# Stationary
# KPSS Statistic: 0.023960
# p-value: 0.100000
# Critical Values:
# 	10%: 0.347
# 	5%: 0.463
# 	2.5%: 0.574
# 	1%: 0.739
# Non-stationary

# %% [markdown]
# #### After differencing the time series data, we tested for stationarity using both the ADF (Augmented Dickey-Fuller) and KPSS (Kwiatkowski-Phillips-Schmidt-Shin) tests. Based on the results of ADF test and the plot of the differenced data, we can conclude that the data became stationary, with no significant trend or seasonality present. This suggests that the differencing transformation was effective in achieving stationarity, which can help to improve the accuracy of any future models and forecasts based on this data. We decide to model the data with ARIMA(1, 1, 1).

# %%
lb_test()
# Out:
#     lb_pvalue
# 1    0.534403
# 2    0.761312
# 3    0.182826
# 4    0.300800
# 5    0.428638
# 6    0.522263
# 7    0.203719
# 8    0.276831
# 9    0.138345
# 10   0.188342
# 11   0.170825
# 12   0.223171

# %% [markdown]
# #### We observed p-values greater than 0.05 for 12 lags, which suggests that there is no significant autocorrelation in the residuals at those lags. This means that the model adequately captures the temporal dependence in the data, and the residuals are essentially random and independent of each other

# %%
auto_arima()
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  835
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -2828.525
# Date:                Thu, 11 May 2023   AIC                           5663.050
# Time:                        20:11:51   BIC                           5677.229
# Sample:                             0   HQIC                          5668.486
#                                 - 835
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8399      0.026     32.838      0.000       0.790       0.890
# ma.L1         -0.9144      0.027    -33.915      0.000      -0.967      -0.862
# sigma2        51.6782      0.459    112.594      0.000      50.779      52.578
# ...

# %% [markdown]
# #### After using pmdarima.auto_arima we see that the function also chooses the same p, d, q values as we did by looking at the plots. So for the forecasting we will use ARIMA(1, 1, 1) model.

# %%
forecast_with_sarima()
# Out:
# The mean squared error for the SARIMAX model is 325.25996594237915

# %% [markdown]
# ## <b>Holt Winter's<a id="hw"></a><b>
# #### From the visualizations above we notice that wherever a trend is present it is additive, and thus we will do exponential smoothing with additive trend. Also, we see that our series are fluctuating a lot around the trend, thus we will pick additive seasonality.

# %%
HW_mse()
# Out:
# The mean squared error for the Holt Winter's model is 305.4537011565769

# %% [markdown]
# #### From the mean squared error funciton we can see that Holt Winter's Exponential Smoothing has lower MSE value than the SARIMA model. Which assumes that this model will capture the data better and will give more accurate results than the SARIMA model.

# %%
plot_HW_pred()

# %% [markdown]
# #### From the plot above it is visible that the HW ES model gave a realistic output compared to the SARIMA model, output of which is a straight line.

# %%
plot_HW_forecast()

# %% [markdown]
# #### We also decided to do forecasting using Holt Winter's model because it captured the data best.

# %% [markdown]
# ## <b>GARCH<a id="garch"></a><b>

# %%
plot_returns()

# %% [markdown]
# #### Previously we saw that the data is not stationary, but now we can see that the returns are stationary despite some fluctuations. We will proceed by ploting the ACF and PACF plots to understand the order of the ARMA model.

# %%
plot_garch_ACF_PACF()

# %% [markdown]
# #### After examining the plots we see that both ACF and PACF have only one significant lag, thus we'll go with ARMA(1,1).

# %%
plot_resid()

# %% [markdown]
# #### It is clear that the p-values for Ljung-Box test are higher than 0.05 for 12 lags, which suggests that there is no significant autocorrelation in the residuals at those lags. This means that the model adequately captures the temporal dependence in the data, and the residuals are essentially random and independent of each other. Which means that the data is independently distributed.

# %%
resid_ACF_PACF()

# %% [markdown]
# #### As there are no significant lags present in the ACF and PACF plots we will proceed with GARCH(1,1) model.

# %%
best_p, best_q = find_best_p_and_q()
# Out:
# Best GARCH(1,2) model with AIC = 6379.08

# %%
forecasts = garch_forecast_with_best_params(best_p, best_q)
# Out:
#           h.01       h.02       h.03       h.04       h.05       h.06  \
# 927  31.044015  40.607973  38.517636  42.342715  43.165283  45.511847
#
#           h.07       h.08       h.09       h.10       h.11      h.12
# 927  47.084871  49.050524  50.816889  52.684408  54.500584  56.34282

# %%
volatility_forecast(forecasts)

# %% [markdown]
# ### Here we can see the forecast of volatility using the GARCH model.
